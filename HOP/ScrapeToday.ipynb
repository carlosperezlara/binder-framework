# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://precisionheatingoil.com/get-price/"

# %%
response = requests.get(url)

soup = BeautifulSoup(response.text)

# %%
#print(soup.prettify())

# %%
myobj = {'wcp_id':2,'zip_code':11790}
response2 = requests.post(url,data=myobj)
soup2 = BeautifulSoup( response2.text )

# %%
print(soup2.h4)
# Out:
# <h4 class="pbd_form_text">50-74 gallons: $<span class="tier_price_option" data-gal="50">6.34</span></h4>

# %%
print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://gmpg.org/xfn/11" rel="profile"/>
#   <title>
#    Order Oil – Check Prices – Precision Heating Oil
#   </title>
#   <meta content="max-image-preview:large" name="robots"/>
#   <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
#   <link href="//s.w.org" rel="dns-prefetch"/>
#   <link href="https://precisionheatingoil.com/feed/" rel="alternate" title="Precision Heating Oil » Feed" type="application/rss+xml"/>
#   <link href="https://precisionheatingoil.com/comments/feed/" rel="alternate" title="Precision Heating Oil » Comments Feed" type="application/rss+xml"/>
#   <script>
# ...

# %%
#print(soup2.prettify())

# %% [markdown]
# <form action="https://precisionheatingoil.com/get-price/" class="pbd_form" method="post">
#     <input name="wcp_id" type="hidden" value="2"/>
#     <div class="zip_input_container">
#         <input autofocus="" id="zip_code" name="zip_code" placeholder="Zip Code" required="" type="text" value=""/>
#         <button class="check_price_btn" type="submit">
#             Check Price
#         </button>
#     </div>
# </form>
